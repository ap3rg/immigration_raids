# %%
import os
import re
import nltk
import time
import spacy
import random
import dateparser
from datetime import datetime
from nltk import sent_tokenize
from striprtf.striprtf import rtf_to_text

nlp = spacy.load("en_core_web_sm")

# %%
# download nltk resources
# nltk.download('punkt', download_dir='/Users/andreaparra/Virtual_envs/python3.12/lib/nltk_data')
# nltk.download('maxent_ne_chunker', download_dir='/Users/andreaparra/Virtual_envs/python3.12/lib/nltk_data')
# nltk.download('words', download_dir='/Users/andreaparra/Virtual_envs/python3.12/lib/nltk_data')
# nltk.download('averaged_perceptron_tagger_eng', download_dir='/Users/andreaparra/Virtual_envs/python3.12/lib/nltk_data')
# nltk.download('maxent_ne_chunker_tab',download_dir='/Users/andreaparra/Virtual_envs/python3.12/lib/nltk_data')

# %% [markdown]
# ### Testing Code

# %%
test_file = "data/nexis uni/Files(486)/No Headline In Original(48).RTF"

with open(test_file, "r", encoding="utf-8") as f:
    rtf_content = f.read()
    plain_text = rtf_to_text(rtf_content)
    
    pattern = re.compile(HIGH_RECALL_DATE_PATTERN, re.IGNORECASE | re.VERBOSE)
    date_matches = pattern.findall(plain_text)
    print(plain_text)
    test = extract_raid_dates(date_matches, "2020-01-01")
    print(date_matches)
    print(test)

# %%
# frist lets sue the regex approach to extract phrases around mention of raids: 

# strict pattern
pat1 = re.compile(
    r"\bimmigration(?:\s+\w+){0,3}\s+raid(?:ed)?\b",
    re.IGNORECASE
)

# high recall
pat2 = re.compile(
    r"(?i)\b(raid(?:ed)?)\b.{0,80}\b(immigration|ICE|undocumented|detain|arrest|federal agents|workers|farmworkers)\b"
    r"|"
    r"\b(immigration|ICE|undocumented|detain|arrest|federal agents|workers|farmworkers)\b.{0,80}\b(raid(?:ed)?)\b"
)



patterns = [pat1, pat2]

def get_raid_sentences(text):
    sentences = sent_tokenize(text)
    raid_sents = []
    for s in sentences:
        if any(p.search(s) for p in patterns):
            raid_sents.append(s)
    return raid_sents

# %%
# regex for Month day, year (e.g., "September 8, 2025")
DATE_PATTERN = re.compile(
    r"(January|February|March|April|May|June|July|August|September|October|November|December)\s+\d{1,2},\s+\d{4}"
)

HIGH_RECALL_DATE_PATTERN = r"""
\b
(
  # Month-name formats: September 8, 2025
  (?:jan|feb|mar|apr|may|jun|jul|aug|sep|sept|oct|nov|dec)[a-z]*
  [\s.-]+
  \d{1,2}(?:st|nd|rd|th)?
  (?:,\s*|\s+)
  \d{4}
  |
  # Day Month-name formats: 8 September 2025
  \d{1,2}(?:st|nd|rd|th)?
  [\s.-]+
  (?:jan|feb|mar|apr|may|jun|jul|aug|sep|sept|oct|nov|dec)[a-z]*
  (?:,\s*|\s+)
  \d{4}
  |
  # ISO-like numeric: 2025-09-08 or 2025/9/8
  \d{4}[-/]\d{1,2}[-/]\d{1,2}
  |
  # Generic numeric: 09/08/2025, 9.8.25, etc.
  \d{1,2}[/.-]\d{1,2}[/.-]\d{2,4}
)
\b
"""

# TODO: include this in processing 
def resolve_date(expr, pub_date):
    # uses publication date as reference to get an absolute date

    dt = dateparser.parse(
        expr,
        settings={
            "RELATIVE_BASE": datetime(pub_date.year, pub_date.month, pub_date.day),
            "PREFER_DATES_FROM": "past",
        },
    )
    return dt.date() if dt else None

def extract_raid_dates(dates, pub_date_str):
    """
    text: full article text (plain text)
    pub_date_str: e.g. 'September 12, 2025'
    returns: list of {'expr': ..., 'date': ...}
    """
    pub_date = dateparser.parse(pub_date_str).date()
    

    results = []
    for date_str in dates:
        abs_date = resolve_date(date_str, pub_date)
        if abs_date:
            results.append({"expr": date_str, "date": abs_date.isoformat()})
            

        # Look into using this bit of code to get even more info out. 
        # for token in doc:
        #     if token.text.lower() in ["monday","tuesday","wednesday","thursday","friday","saturday","sunday"] \
        #        and token.ent_type_ != "DATE":
        #         expr = token.text
        #         abs_date = resolve_date(expr, pub_date)
        #         if abs_date:
        #             results.append({"expr": expr, "date": abs_date.isoformat(), "sentence": s})

    # deduplicate by date
    seen = set()
    unique = []
    for r in results:
        key = (r["date"], r["expr"])
        if key not in seen:
            seen.add(key)
            unique.append(r)
            
    return unique

# %%
#Geopolitical Entity, location and faciliyt
LOCATION_LABELS = {"GPE", "LOC", "FAC"} 


# this fucniton I didn't really make, it uses spacy to extract 
# locations in sentences that mention 'raid'
def extract_locations_from_doc(doc):
    locations = set()

    for sent in doc.sents:
        # only focus on sentences that include 'raid'
        if not any(tok.lemma_.lower() == "raid" for tok in sent):
            continue

        # 1) NER-based locations in this sentence
        for ent in sent.ents:
            if ent.label_ in LOCATION_LABELS:
                locations.add(ent.text.strip())

        # 2) Dependency-based: raid + prepositions (in/at/near/on)
        for tok in sent:
            if tok.lemma_.lower() == "raid":
                for child in tok.children:
                    if child.dep_ == "prep" and child.text.lower() in {"in", "at", "near", "on"}:
                        pobj = next((c for c in child.children if c.dep_ == "pobj"), None)
                        if pobj is not None:
                            # collect the full span of the pobj subtree
                            subtree_tokens = list(pobj.subtree)
                            span_text = doc[subtree_tokens[0].i : subtree_tokens[-1].i + 1].text
                            locations.add(span_text.strip())

    return list(locations)

# %%
ARREST_LEMMAS = {"arrest", "detain"}
PEOPLE_NOUNS = {"people", "persons", "workers", "employees",
                "immigrants", "farmworkers", "detainees", "individuals"}

APPROX_WORDS = {"dozens", "scores", "hundreds", "thousands"}

def parse_int_safe(text):
    # remove commas and try to cast
    try:
        return int(text.replace(",", ""))
    except ValueError:
        return None

def extract_arrest_counts_from_doc(doc):
    results = []

    for sent in doc.sents:
        # only if sentence mentions arrest/detain/raid-ish things
        if not any(tok.lemma_.lower() in ARREST_LEMMAS for tok in sent):
            continue

        for tok in sent:
            if tok.lemma_.lower() in ARREST_LEMMAS and tok.pos_ == "VERB":
                # 1) passive subject: "360 people were arrested"
                for child in tok.children:
                    if child.dep_ in {"nsubjpass", "dobj", "obj"} and child.lemma_.lower() in PEOPLE_NOUNS:
                        # look for numeric modifiers of that noun
                        for gchild in child.children:
                            if gchild.dep_ == "nummod":
                                val = gchild.text
                                approx = val.lower() in APPROX_WORDS
                                num_val = parse_int_safe(val) if not approx else None
                                results.append({
                                    "value": num_val if num_val is not None else val,
                                    "approx": approx,
                                    "sentence": sent.text.strip()
                                })

                # 2) "arrested about 360 people" – number attached to the verb
                # look for NUM children and then a people noun
                num_child = None
                people_child = None
                for child in tok.children:
                    if child.pos_ == "NUM":
                        num_child = child
                    if child.lemma_.lower() in PEOPLE_NOUNS:
                        people_child = child
                if num_child is not None and people_child is not None:
                    val = num_child.text
                    approx = val.lower() in APPROX_WORDS
                    num_val = parse_int_safe(val) if not approx else None
                    results.append({
                        "value": num_val if num_val is not None else val,
                        "approx": approx,
                        "sentence": sent.text.strip()
                    })

        # 3) phrases like "netted hundreds of arrests"
        for tok in sent:
            if tok.lemma_.lower() == "net" and tok.pos_ == "VERB":
                # look for "hundreds of arrests"
                for child in tok.children:
                    if child.pos_ == "NUM" or child.text.lower() in APPROX_WORDS:
                        # check that "arrests" appears somewhere nearby
                        if any(t.lemma_.lower() == "arrest" and t.pos_ == "NOUN" for t in sent):
                            val = child.text
                            approx = True  # "hundreds" etc.
                            results.append({
                                "value": val,
                                "approx": approx,
                                "sentence": sent.text.strip()
                            })

    return results

# %%
def analyze_raid_snippet(text):
    doc = nlp(text)
    locations = extract_locations_from_doc(doc)
    arrests = extract_arrest_counts_from_doc(doc)
    return {
        "locations": locations,
        "arrest_counts": arrests
    }

# %% [markdown]
# TODO:
#
# 1. Add timer and move on to next file if it gets stuck
# 2. Write data to file as we go to avoid data loss
# 3. Figure out way to process resulting data file
#     - Consolidate data into specific raids
#         - Extract likely date (date distribution?)
#         - Geocode
#         - Themes(?)
#     - Assign value of "virality" of a given raid (how represented it is in the news)
# 4. Validation
#     - Select some articles with and without raids identified and validate manually
#     - See if mapped raids correspoond to general trends of ICE arrests/abductions

# %%
start_time = time.perf_counter()
# Your code to be timed
time.sleep(1) # Simulate some work
end_time = time.perf_counter()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time:.4f} seconds")

# %%
batch = "96-216"
dir_path = "data/nexis uni/pg" + batch

PROCESS_DATES = True
OUTPUT_FILE = f"data/nexis uni/processed/processed_data_{batch}.txt"


data = []
files_processed = []
errors = []
idx = 0

with open(OUTPUT_FILE, "w", encoding="utf-8") as out_f:
    
    for file in os.listdir(dir_path):    
        if "doclist.RTF" in file:
            continue
        # only process RTF files
        if ".RTF" in file:
            clean_name = re.sub(r"\(\d+\)\.RTF$", ".RTF", file, flags=re.IGNORECASE)
            if (clean_name in files_processed) and not (clean_name.startswith("No Headline In Original")):
                print("Skipping already processed file:", file)
                continue
            file_path = os.path.join(dir_path, file)
            print(f"Processing file {idx}/{len(os.listdir(dir_path))}: {file}")
            with open(file_path, "r", encoding="utf-8") as f:
                data_record = {}
                data_record["file_name"] = file
                rtf_content = f.read()
                plain_text = rtf_to_text(rtf_content)
                
                lines = [line.strip() for line in plain_text.splitlines() if line.strip()]
                
                # get all dats in the articel (we will then process based on pubdate)
                pattern = re.compile(HIGH_RECALL_DATE_PATTERN, re.IGNORECASE | re.VERBOSE)
                date_matches = pattern.findall(plain_text)
                
                for i, line in enumerate(lines):
                    if line:
                        # stop parsing (based on text structure)
                        if line.startswith("Classification"):
                            break
                        # extract date
                        if line.startswith("Copyright"):
                            # the date should be the line immediately before this
                            if i == 0:
                                date_line = None
                            else:  
                                date_line = lines[i - 1]
                                # extract date pattern
                                match = DATE_PATTERN.search(date_line)
                                if match:
                                    date_str = match.group(0)
                            # recrod date
                            data_record["pub-date"] = date_str
                        else:
                        # assume fist date found is publication date
                            data_record["pub-date"] = date_matches[0] if date_matches else None
                        
                        data_record["raid_dates"] = date_matches
                        if data_record["pub-date"] and PROCESS_DATES:
                            # for later cause it is really slow
                            # raid_dates = extract_raid_dates(date_matches, data_record["pub-date"])
                            # if more than 10 dates in file, shuffle and pick first 10
                            if len(date_matches) > 10:
                                random.shuffle(date_matches)
                                date_matches = date_matches[:10]
                            try:
                                raid_dates = [dateparser.parse(d).date() for d in date_matches if dateparser.parse(d)]
                                data_record["raid_dates"] = raid_dates
                            except AttributeError:
                                errors.append(file)
                            
                        # extract raid sentences
                        raid_sentence = get_raid_sentences(line)
                        if raid_sentence:
                            # add new found sentenses
                            found_sentences = data_record["raid_sentences"] if "raid_sentences" in data_record else []
                            found_sentences.extend(raid_sentence)
                            data_record["raid_sentences"] = found_sentences
                            
                            # analyze each sentence
                            raid_analysis = analyze_raid_snippet(raid_sentence[0])
                            found_raids = data_record["raid_analysis"] if "raid_analysis" in data_record else []
                            found_raids.append(raid_analysis)
                            data_record["raid_analysis"] = found_raids
                # only keep recrods where raids were found
                if "raid_analysis" in data_record:
                    out_f.write(str(data_record) + "\n")
                    data.append(data_record)
                # document all files that were processed
                files_processed.append(file)
                idx += 1

    
data
# Out:
# Processing file 0/495: BAY BUZZ_ POLITICAL NEWS OF TAMPA BAY.RTF
# Processing file 1/495: Immigration blitz nets nearly 100 meatworkers FRAUD RACKET.RTF
# Processing file 2/495: The Home Secretary is a walking disaster.RTF
# Processing file 3/495: Religion News in Brief(2).RTF
# Processing file 4/495: Intercepté en pleine mer(2).RTF
# Processing file 5/495: MORE TROUBLE FOR SMITH AS MOLE SPARKS MYSTERY OF DOZEN LEAKS.RTF
# Processing file 6/495: Record heroin haul made in Britain and SA(2).RTF
# Processing file 7/495: Fed_ Eighteen illegal workers found hiding in Vic , WA.RTF
# Processing file 8/495: Jurors find former Agriprocessors slaughterhouse manager not guilty of child labour violations(2).RTF
# Processing file 9/495: Two Canadians tied to controversial U.S. mosque arrested(2).RTF
# Processing file 10/495: Illegal immigrants cultivated cannabis in Cheltenham.RTF
# Processing file 11/495: Israel to Deport Aid Ship Activists.RTF
# Processing file 12/495: Saturday Review_ ARTS_ Nowhere to hide_ His critics view him as a sadist yet his new film won the Pa.RTF
# Processing file 13/495: HICKEY HICKEY.RTF
# Processing file 14/495: Mandarins under fire as MP Green cleared in leaks inquiry Tories accuse officials of wasting police.RTF
# Processing file 15/495: 2 arrested in Millard deputy slaying; prosecutors to seek death penalty.RTF
# Processing file 430/495: Letters special_ Your thoughts on the election.RTF
# Processing file 431/495: Prévisions internationales du dimanche 6 juin 2010 (actualisées à 15H30 GMT).RTF
# Processing file 432/495: Federal Agents Arrest Bus Driver and His Father in a Terror Inquiry.RTF
# Processing file 433/495: 'Approved' college sells diplomas to students and fakes attendance records Immigration bodies are fo.RTF
# Processing file 434/495: Urban sanctuaries.RTF
# Processing file 435/495: Iowa agrees to cut fine against slaughterhouse.RTF
# Processing file 436/495: Tamils ride their luck ASYLUM.RTF
# Processing file 437/495: Undercover reporter attacked.RTF
# Processing file 438/495: ANIMAL WELFARE_CRUELTY BARBARIC IN ITSELF, TIED TO OTHER OFFENSES.RTF
# Processing file 439/495: Rachel Corrie_ les militants expulsés, Israël pressé d'accepter une enquête.RTF
# Processing file 440/495: Two Canadians tied to controversial U.S. mosque arrested.RTF
# Processing file 441/495: 180 immigration offenders removed in past year.RTF
# Processing file 442/495: Fed_ Govt blinded by dollars over education rorts, academic says.RTF
# Processing file 443/495: Misery follows the 'jungle camp' raid.RTF
# Processing file 444/495: ALAS SMITH HOME SECRETARY ON THE BRINK ..And Johnson could replace you.RTF
# Processing file 445/495: Empire building COVER STORY.RTF
# Processing file 446/495: HighLights of the AAP National Wire at 14_30, July 29.RTF
# Processing file 447/495: National_ Campaign 2010_ Conservatives_ Cameron may be a good campaigner. But he has not had a good.RTF
# Processing file 448/495: MP may lose citizenship for joining flotilla GAZA_ THE AFTERMATH.RTF
# Processing file 449/495: Stopping Arizona.RTF
# Processing file 450/495: Chinese minors and porn DVD factory found in garda swoop on Dublin apartment.RTF
# Processing file 451/495: Charges stay against Iowa slaughterhouse manager.RTF
# Skipping already processed file: National Briefs. Stories may have moved as regional or national separates on the Canwest News Servic(2).RTF
# Skipping already processed file: BRIT FURY AS U.N. SAYS 'LET EM IN' 1,000 from Jungle migrant camp may walk into the UK(2).RTF
# [{'file_name': 'Religion News in Brief(2).RTF',
#   'pub-date': 'March 10, 2010',
#   'raid_dates': [datetime.date(2010, 3, 10), datetime.date(2010, 3, 11)],
#   'raid_sentences': ['POSTVILLE, Iowa (AP) _ Ten undocumented aliens who were arrested and charged in the May 2008 raid at the former Agriprocessors kosher slaughterhouse in Postville have learned that they will be deported by March 31.'],
#   'raid_analysis': [{'locations': ['the former Agriprocessors', 'Postville'],
#     'arrest_counts': []}]},
#  {'file_name': 'Jurors find former Agriprocessors slaughterhouse manager not guilty of child labour violations(2).RTF',
#   'pub-date': 'June 7, 2010',
#   'raid_dates': [datetime.date(2010, 6, 7), datetime.date(2010, 6, 17)],
#   'raid_sentences': ['Rubashkin had been charged following a May 2008 immigration raid in which 389 workers were arrested.',
#    'The alleged violations occurred between September 2007 and May 2008, when the plant was raided by federal immigration agents.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []},
#    {'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'HICKEY HICKEY.RTF',
#   'pub-date': 'May 26, 2009',
#   'raid_dates': [datetime.date(2009, 5, 26), datetime.date(2009, 5, 26)],
#   'raid_sentences': ["Smith has endured a torrid few months following the controversial police raid on Conservative immigration minister Damian Green's office and the humiliating revelations that her husband had watched adult films at the taxpayers' expense."],
#   'raid_analysis': [{'locations': ["Conservative immigration minister Damian Green's office"],
#     'arrest_counts': []}]},
#  {'file_name': "Trustee_ Iowa slaughterhouse sale 'in the works'.RTF",
#   'pub-date': 'May 22, 2009',
#   'raid_dates': [datetime.date(2009, 5, 22), datetime.date(2009, 5, 23)],
#   'raid_sentences': ['Immigration agents raided the Agriprocessors slaughterhouse in Postville in May 2008 and arrested 389 people, most from Mexico and Guatemala.'],
#   'raid_analysis': [{'locations': ['Mexico', 'Guatemala', 'Postville'],
#     'arrest_counts': [{'value': 389,
#       'approx': False,
#       'sentence': 'Immigration agents raided the Agriprocessors slaughterhouse in Postville in May 2008 and arrested 389 people, most from Mexico and Guatemala.'}]}]},
#  {'file_name': 'Stash house raided; more than 50 undocumented immigrants apprehended_ Agents find mortar as 52 peopl.RTF',
#   'pub-date': 'April 30, 2010',
#   'raid_dates': [datetime.date(2010, 4, 30), datetime.date(2010, 5, 1)],
#   'raid_sentences': ['Stash house raided; more than 50 undocumented immigrants apprehended: Agents find mortar as 52 people taken into federal custody'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Mass. factory in 2007 immigration raid to close.RTF',
#   'pub-date': 'May 29, 2009',
#   'raid_dates': [datetime.date(2009, 5, 29), datetime.date(2009, 5, 30)],
#   'raid_sentences': ['factory in 2007 immigration raid to close',
#    'A Massachusetts leather-goods factory raided in 2007 by immigration agents will close.',
#    'Federal agents raided the plant and arrested more than 360 undocumented workers in 2007.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []},
#    {'locations': ['2007', 'Massachusetts'], 'arrest_counts': []},
#    {'locations': [], 'arrest_counts': []}]},
#  {'file_name': '180 illegal workers deported from region after agency raids Nearly 200 foreign nationals were deport.RTF',
#   'pub-date': 'January 2, 2010',
#   'raid_dates': [datetime.date(2010, 1, 2), datetime.date(2010, 1, 3)],
#   'raid_sentences': ['Five illegal workers from Malaysia and China were arrested during a raid at the Golden Panda in Newport Street, Tiverton, Mid-Devon, last January.'],
#   'raid_analysis': [{'locations': ['China',
#      'the Golden Panda in Newport Street,',
#      'Newport Street',
#      'the Golden Panda',
#      'Malaysia',
#      'Tiverton'],
#     'arrest_counts': []}]},
#  {'file_name': 'Jobless numbers jump.RTF',
#   'pub-date': 'March 12, 2009',
#   'raid_dates': [datetime.date(2009, 3, 12), datetime.date(2009, 3, 12)],
#   'raid_sentences': ['Even before the full impact of the recession took hold, the region was taking hits from the May 2008 Postville immigration raid and heavy spring flooding.'],
#   'raid_analysis': [{'locations': ['Postville'], 'arrest_counts': []}]},
#  {'file_name': 'Immigration raid on supermarket(2).RTF',
#   'pub-date': 'March 11, 2009',
#   'raid_dates': [datetime.date(2009, 3, 11), datetime.date(2009, 6, 11)],
#   'raid_sentences': ['Immigration raid on supermarket',
#    'Immigration officers have raided a supermarket today as part of an ongoing crackdown on illegal working in Stoke-on-Trent.'],
#   'raid_analysis': [{'locations': ['supermarket'], 'arrest_counts': []},
#    {'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Slaughterhouse unlikely to pay reduced fines.RTF',
#   'pub-date': 'July 28, 2009',
#   'raid_dates': [datetime.date(2009, 7, 28), datetime.date(2009, 7, 29)],
#   'raid_sentences': ['Agriprocessors was the site of a major immigration raid in 2008.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Chinese workers held in swoop Chinese buffet is raided by officials.RTF',
#   'pub-date': 'May 29, 2009',
#   'raid_dates': [datetime.date(2009, 5, 29), datetime.date(2009, 5, 29)],
#   'raid_sentences': ['Chinese workers held in swoop; Chinese buffet is raided by officials'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Wayne Law Alumna Navigates Winding Road, Finds Rewarding Career in Immigration Law.RTF',
#   'pub-date': 'January 4, 2010',
#   'raid_dates': [datetime.date(2010, 1, 4),
#    datetime.date(2008, 8, 25),
#    datetime.date(2010, 1, 5)],
#   'raid_sentences': ['Currently, Ice is working on termination and suppression motions that MIRA filed in the New Orleans immigration court on behalf of some former Howard Industries, Inc. workers who were arrested on Aug. 25, 2008, in the largest single worksite enforcement raid in the history of U.S. immigration.'],
#   'raid_analysis': [{'locations': ['New Orleans',
#      'U.S.',
#      'the history of U.S. immigration'],
#     'arrest_counts': []}]},
#  {'file_name': 'Slaugherhouse manager acquitted in kid labor trial.RTF',
#   'pub-date': 'June 7, 2010',
#   'raid_dates': [datetime.date(2010, 6, 7), datetime.date(2010, 6, 8)],
#   'raid_sentences': ['Rubashkin was charged in both cases following a May 2008 immigration raid at the former Agriprocessors slaughterhouse in Postville, where 389 workers, including children, were arrested on immigration charges.'],
#   'raid_analysis': [{'locations': ['the former Agriprocessors', 'Postville'],
#     'arrest_counts': []}]},
#  {'file_name': 'Controversial foreign worker program includes Guelph mushroom farm.RTF',
#   'pub-date': 'November 1, 2009',
#   'raid_dates': [datetime.date(2009, 11, 1),
#    datetime.date(2008, 12, 1),
#    datetime.date(2009, 11, 24)],
#   'raid_sentences': ['After one raid, about 40 workers from Thailand with expired work permits were sent to a detention centre in Rexdale.'],
#   'raid_analysis': [{'locations': ['Rexdale', 'Thailand'],
#     'arrest_counts': []}]},
# ...
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': "Mass. factory closed, site of '07 immigration raid.RTF",
#   'pub-date': 'May 29, 2009',
#   'raid_dates': [datetime.date(2009, 5, 29), datetime.date(2009, 5, 30)],
#   'raid_sentences': ["factory closed, site of '07 immigration raid",
#    'A New Bedford leather-goods factory raided in 2007 by immigration agents will close its doors by July 31, the company that owns the plant announced Friday.',
#    'In 2007, federal immigration agents raided the plant and arrested 361 undocumented workers.',
#    'U.S. Immigration and Customs Enforcement said the raid was properly handled.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []},
#    {'locations': ['New Bedford', '2007'], 'arrest_counts': []},
#    {'locations': ['2007'], 'arrest_counts': []},
#    {'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Lutheran Bishops Advocate for Rights of Immigrants and Refugees.RTF',
#   'pub-date': 'October 30, 2009',
#   'raid_dates': [datetime.date(2009, 10, 30),
#    datetime.date(2008, 5, 12),
#    datetime.date(2009, 10, 31)],
#   'raid_sentences': ['According to Ullestad, the children and community of Postville, Iowa, were "adversely affected" by the U.S. Immigration and Customs Enforcement (ICE) raid on May 12, 2008, the largest U.S. immigration raid.'],
#   'raid_analysis': [{'locations': ['May 12, 2008, the largest U.S. immigration raid',
#      'Iowa',
#      'U.S.',
#      'Postville'],
#     'arrest_counts': []}]},
#  {'file_name': "It's crunch day for Smith as Commons goes back to work.RTF",
#   'pub-date': 'April 18, 2009',
#   'raid_dates': [datetime.date(2009, 4, 18), datetime.date(2009, 4, 18)],
#   'raid_sentences': ['JACQUI SMITH is gearing up for a crunch Monday when she faces MPs for the first time since being humiliated over the police raid on Shadow Immigration Minister Damian Green.'],
#   'raid_analysis': [{'locations': ['Shadow Immigration Minister Damian Green'],
#     'arrest_counts': []}]},
#  {'file_name': 'State agrees to cut fine against slaughterhouse.RTF',
#   'pub-date': 'July 27, 2009',
#   'raid_dates': [datetime.date(2009, 7, 27), datetime.date(2009, 7, 28)],
#   'raid_sentences': ['Agriprocessors was the site of a massive immigration raid in 2008.'],
#   'raid_analysis': [{'locations': ['2008'], 'arrest_counts': []}]},
#  {'file_name': 'Navarette_ Confused on immigration.RTF',
#   'pub-date': 'March 12, 2009',
#   'raid_dates': [datetime.date(2009, 3, 12), datetime.date(2009, 3, 13)],
#   'raid_sentences': ['Yet just one week later, Immigration and Customs Enforcement carried out the first major worksite raid under the Obama administration.',
#    "Testifying recently before Congress, Homeland Security Secretary Janet Napolitano claimed that she didn't know about the Bellingham raid beforehand and that she has asked ICE for a review of the operation."],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []},
#    {'locations': [], 'arrest_counts': []}]},
#  {'file_name': "265 deported as crackdown on N.Wales' illegals bites BORDER AGENCY'S 66 RAIDS IN 2009.RTF",
#   'pub-date': 'January 4, 2010',
#   'raid_dates': [datetime.date(2010, 1, 4), datetime.date(2010, 1, 4)],
#   'raid_sentences': ['Fined pounds 10,000 after two workers from Vietnam were found in a raid in March Ming Wah Fish Bar, Cefndy Road, RhylFined pounds 5,000 after illegal worker from China found in raid in November 2008.',
#    'Now under new ownership The Fry Inn, Water Street, Rhyl Fined pounds 15,000 after three workers from Pakistan found working in raid in September 2008.',
#    "Now under new ownership G & R Newsagents, High Street, Connah's Quay Fined pounds 5,000 after one illegal worker from Sri Lanka found in raid in January.Anglesey House, High Street, LlangefniFined pounds 15,000 after three Bangladeshi workers found in raid in February 2009.Maa Tandoori, High Street, Connah's QuayFined pounds 10,000 after two illegal workers from Bangladesh found in raid in March."],
#   'raid_analysis': [{'locations': ['Cefndy Road',
#      'China',
#      'March Ming Wah Fish Bar, Cefndy Road, RhylFined pounds 5,000 after illegal worker from China',
#      'Vietnam'],
#     'arrest_counts': []}]},
#  {'file_name': 'Damian Green_ I was threatened with life imprisonment by police.RTF',
#   'pub-date': 'April 17, 2009',
#   'raid_dates': [datetime.date(2009, 4, 17), datetime.date(2009, 4, 17)],
#   'raid_sentences': ['The Cabinet Office said it took the decision to call in the police, and the police decided to arrest Green and raid his Commons office.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Two former brothels for sale at knock-down price.RTF',
#   'pub-date': 'May 1, 2010',
#   'raid_dates': [datetime.date(2010, 5, 1),
#    datetime.date(2006, 11, 20),
#    datetime.date(2010, 5, 1)],
#   'raid_sentences': ['The prosecutions came about after a successful raid of the premises by CAB, gardaí, Revenue and immigration officials on November 20, 2006.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Grenades sold to undercover authorities overshadow human bones found at San Juan property.RTF',
#   'pub-date': 'October 30, 2009',
#   'raid_dates': [datetime.date(2009, 10, 30), datetime.date(2009, 10, 30)],
#   'raid_sentences': ['Federal agents and the San Juan police SWAT team raided the property Wednesday morning, finding weapons, firearms and a blood-stained altar alongside human and animal bones in the backyard.'],
#   'raid_analysis': [{'locations': ['San Juan'], 'arrest_counts': []}]},
#  {'file_name': 'No Headline In Original(5).RTF',
#   'pub-date': 'May 1, 2010',
#   'raid_dates': [datetime.date(2010, 5, 1),
#    datetime.date(1997, 5, 1),
#    datetime.date(2010, 5, 5)],
#   'raid_sentences': ['One couple picked up in a knitwear factory during an immigration raid believed they had every right to be in this country.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Officers swoop on businesses in raids.RTF',
#   'pub-date': 'March 12, 2009',
#   'raid_dates': [datetime.date(2009, 3, 12), datetime.date(2009, 8, 21)],
#   'raid_sentences': ['Seven illegal Chinese workers were found when UKBA officials acting on intelligence raided a Chinese takeaway in Leek.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Iowa lawmakers take up health care.RTF',
#   'pub-date': 'March 9, 2009',
#   'raid_dates': [datetime.date(2009, 3, 9), datetime.date(2009, 3, 10)],
#   'raid_sentences': ['An expansion of health care coverage for children and a bill prompted by a huge immigration raid are among topics expected to be a focus at the Iowa Legislature this week.',
#    'House Speaker Pat Murphy says the proposal was inspired by labor law violations alleged at the Agriprocessors slaughterhouse in Postville following an immigration raid last May.'],
#   'raid_analysis': [{'locations': ['the Iowa Legislature'],
#     'arrest_counts': []},
#    {'locations': ['Postville'], 'arrest_counts': []}]},
#  {'file_name': "We won't tolerate cheating of foreign students_ Australian minister.RTF",
#   'pub-date': 'July 28, 2009',
#   'raid_dates': [datetime.date(2009, 7, 28), datetime.date(2009, 7, 29)],
#   'raid_sentences': ['After the incident, police and immigration officials Monday raided the office of an agent allegedly involved in exploiting foreign students.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Restaurateur could face £80,000 fines if staff were working illegally.RTF',
#   'pub-date': 'September 19, 2009',
#   'raid_dates': [datetime.date(2009, 9, 19), datetime.date(2009, 9, 20)],
#   'raid_sentences': ['Two children were handed into the care of Torbay Council yesterday after an immigration raid at a Torquay town centre Chinese restaurant.',
#    'The immigration raid took place on Thursday evening and six other people were also arrested for working illegally - including a Chinese man and woman, both are failed asylum seekers who did not leave the UK as required when their claims for international protection were turned down.',
#    'He was issued with an on-the-spot penalty notice for employing the eight immigrant workers following the raid.'],
#   'raid_analysis': [{'locations': ['a Torquay town centre Chinese restaurant'],
#     'arrest_counts': []},
#    {'locations': ['UK'],
#     'arrest_counts': [{'value': 'six',
#       'approx': False,
#       'sentence': 'The immigration raid took place on Thursday evening and six other people were also arrested for working illegally - including a Chinese man and woman, both are failed asylum seekers who did not leave the UK as required when their claims for international protection were turned down.'}]},
#    {'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Say sorry for this.RTF',
#   'pub-date': 'May 1, 2010',
#   'raid_dates': [datetime.date(2010, 5, 1), datetime.date(2012, 7, 16)],
#   'raid_sentences': ['They have presided over the destruction of the healthy economy inherited in 1997, allowed uncontrolled immigration, reneged on a referendum on the EU, restrained civil liberty and free speech, raided our pensions, sold off our gold at the bottom of the market, failed spectacularly to improve educational standards and deliberately trashed our culture.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'ROID BUST YIELDS REAL PRO. Suspect to cops_ I sold to players.RTF',
#   'pub-date': 'May 28, 2009',
#   'raid_dates': [datetime.date(2009, 5, 28), datetime.date(2009, 5, 28)],
#   'raid_sentences': ['Former bodybuilder and personal trainer Richard Thomas and his wife, Sandra, are under arrest after Polk County, Fla. sheriffs raided their home in Lakeland, Fla. on Tuesday and netted a large cache of firearms and steroids that they allegedly sold to Washington Nationals and Capitals players and other pro athletes.'],
#   'raid_analysis': [{'locations': ['Tuesday',
#      'Lakeland',
#      'Polk County',
#      'Fla.'],
#     'arrest_counts': []}]},
#  {'file_name': 'Now Showing.RTF',
#   'pub-date': 'September 18, 2009',
#   'raid_dates': [datetime.date(2009, 9, 18), datetime.date(2009, 9, 17)],
#   'raid_sentences': ['A REFUGEE jumps ship during a raid by immigration police and winds up on a nude beach at a Greek holiday resort.'],
#   'raid_analysis': [{'locations': ['a Greek holiday resort'],
#     'arrest_counts': []}]},
#  {'file_name': "RI's only law school starts immigration law clinic.RTF",
#   'pub-date': 'September 19, 2009',
#   'raid_dates': [datetime.date(2009, 9, 19), datetime.date(2009, 9, 20)],
#   'raid_sentences': ['Federal agents in March 2007 raided a leather goods factory in New Bedford, Mass., arresting 361 workers mostly women from Central America on federal immigration charges.',
#    'Six courthouses were raided in July 2008 for having suspected illegal immigrant cleaning workers; the following month, a Chinese immigrant held at the Donald W. Wyatt Detention Facility in Central Falls died of advanced liver cancer after being neglected by staff there.'],
#   'raid_analysis': [{'locations': ['March 2007',
#      'New Bedford',
#      'Mass.',
#      'Central America'],
#     'arrest_counts': []},
#    {'locations': ['July 2008', 'the Donald W. Wyatt Detention Facility'],
#     'arrest_counts': []}]},
#  {'file_name': 'Immigration raid on supermarket.RTF',
#   'pub-date': 'March 11, 2009',
#   'raid_dates': [datetime.date(2009, 3, 11), datetime.date(2009, 3, 12)],
#   'raid_sentences': ['Immigration raid on supermarket',
#    'Immigration officers have raided a supermarket today as part of an ongoing crackdown on illegal working in Stoke-on-Trent.'],
#   'raid_analysis': [{'locations': ['supermarket'], 'arrest_counts': []},
#    {'locations': [], 'arrest_counts': []}]},
#  {'file_name': "INFORMATION ISSUED BY U.S. ATTORNEY'S OFFICE FOR SOUTHERN DISTRICT OF MISSISSIPPI ON MARCH 3_ OWNER,.RTF",
#   'pub-date': 'May 27, 2009',
#   'raid_dates': [datetime.date(2009, 5, 27),
#    datetime.date(2009, 2, 18),
#    datetime.date(2009, 5, 5),
#    datetime.date(2009, 5, 27)],
#   'raid_sentences': ['In addition, the indictment also recounts the arrest of 15 illegal alien employees of Stix Restaurant from May 2006 through March 2008, when the restaurant was ultimately raided by U.S. Immigration and Customs Enforcement ("ICE"), where a total of nine additional illegal aliens were arrested.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Iowa _ Testimony In Slaughterhouse Case.RTF',
#   'pub-date': 'October 30, 2009',
#   'raid_dates': [datetime.date(2009, 10, 30), datetime.date(2009, 10, 30)],
#   'raid_sentences': ['A former slaughterhouse supervisor testified that the plant scrambled to get workers new identification documents the night before a huge immigration raid.',
#    'The man, Carlos Guerrero-Espinoza, said managers at the slaughterhouse, Agriprocessors Inc. in Postville, provided permanent-resident cards to 20 employees and had them fill out new applications the night before the May 2008 raid at the plant, where nearly 400 workers were arrested.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': "Fed_ Govt _won't tolerate_ abuse of foreign student system.RTF",
#   'pub-date': 'July 28, 2009',
#   'raid_dates': [datetime.date(2009, 7, 28), datetime.date(2009, 7, 29)],
#   'raid_sentences': ['Federal police and immigration officials on Monday raided the offices of a Sydney migration agent allegedly involved in a scam to exploit students.'],
#   'raid_analysis': [{'locations': ['Sydney', 'Monday'], 'arrest_counts': []}]},
#  {'file_name': "'Will she be fined just as we were_'.RTF",
#   'pub-date': 'September 18, 2009',
#   'raid_dates': [datetime.date(2009, 9, 18), datetime.date(2009, 9, 18)],
#   'raid_sentences': ['Immigration officials raided their business after a tip-off, and the couple were fined  pounds 5,000 for each illegal worker.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Briefly.RTF',
#   'pub-date': 'July 29, 2009',
#   'raid_dates': [datetime.date(2009, 7, 29),
#    datetime.date(2008, 5, 2),
#    datetime.date(2009, 11, 23),
#    datetime.date(2009, 7, 28)],
#   'raid_sentences': ["Justice Daniel Goundar ruled investigations were pending and other restricted document belonging to immigration department were also discovered at Toga's home during a raid."],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Iowa agrees to cut fine against slaughterhouse.RTF',
#   'pub-date': 'July 27, 2009',
#   'raid_dates': [datetime.date(2009, 7, 27), datetime.date(2009, 7, 28)],
#   'raid_sentences': ['The fines came five months after a huge immigration raid in which federal agents arrested 389 workers.'],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Undercover reporter attacked.RTF',
#   'pub-date': 'July 28, 2009',
#   'raid_dates': [datetime.date(2009, 7, 28), datetime.date(2009, 7, 28)],
#   'raid_sentences': ["Following the programme's screening yesterday, police and immigration officials raided the offices of a migration agent."],
#   'raid_analysis': [{'locations': [], 'arrest_counts': []}]},
#  {'file_name': 'Fed_ Govt blinded by dollars over education rorts, academic says.RTF',
#   'pub-date': 'July 27, 2009',
#   'raid_dates': [datetime.date(2009, 7, 27), datetime.date(2009, 7, 28)],
#   'raid_sentences': ['His comments come as federal police and immigration officials raided the offices of a Sydney migration agent allegedly involved in a scam to exploit foreign students.'],
#   'raid_analysis': [{'locations': ['Sydney'], 'arrest_counts': []}]},
#  {'file_name': 'Charges stay against Iowa slaughterhouse manager.RTF',
#   'pub-date': 'September 18, 2009',
#   'raid_dates': [datetime.date(2009, 9, 18), datetime.date(2009, 9, 19)],
#   'raid_sentences': ['He was an executive at the former Agriprocessors Inc. plant in Postville, the site of a massive immigration raid in May 2008.'],
#   'raid_analysis': [{'locations': ['May 2008', 'Postville'],
#     'arrest_counts': []}]}]

# %%
print(f"Files with errors: {len(errors)}")
print(f"Files processed: {len(files_processed)}")
print(f"Records with raids found: {len(data)}")
